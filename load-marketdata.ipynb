# %% [markdown]
# # Load crypto market data

# %%
# !git clone https://github.com/binance/binance-public-data.git
# Out:
# Cloning into 'binance-public-data'...
# remote: Enumerating objects: 265, done.
# remote: Counting objects: 100% (182/182), done.
# remote: Compressing objects: 100% (124/124), done.
# remote: Total 265 (delta 110), reused 110 (delta 58), pack-reused 83
# Receiving objects: 100% (265/265), 6.50 MiB | 30.54 MiB/s, done.
# Resolving deltas: 100% (138/138), done.

# %%
fromDate='2017-08-01'
toDate='2022-08-31'

# %%
# !python3 binance-public-data/python/download-kline.py -t spot -s BTCUSDT -i 1m -startDate 2017-08-01 -endDate 2022-08-31 -skip-daily 1 -folder ~/marketdata/btc/
# !python3 binance-public-data/python/download-kline.py -t spot -s ETHUSDT -i 1m -startDate 2017-08-01 -endDate 2022-08-31 -skip-daily 1 -folder ~/marketdata/eth/
# Out:
# Found 1 symbols
# [1/1] - start download monthly BTCUSDT klines
#
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2017-08.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2017-09.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2017-10.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2017-11.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2017-12.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2018-01.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2018-02.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2018-03.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2018-04.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2018-05.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2018-06.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2018-07.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2018-08.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2018-09.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2018-10.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2018-11.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2018-12.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2019-01.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2019-02.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2019-03.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2019-04.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2019-05.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2019-06.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2019-07.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2019-08.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2019-09.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2019-10.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2019-11.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2019-12.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2020-01.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2020-02.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2020-03.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2020-04.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2020-05.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2020-06.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2020-07.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2020-08.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2020-09.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2020-10.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2020-11.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2020-12.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2021-01.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2021-02.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2021-03.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2021-04.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2021-05.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2021-06.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2021-07.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2021-08.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2021-09.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2021-10.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2021-11.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2021-12.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2022-01.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2022-02.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2022-03.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2022-04.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2022-05.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2022-06.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2022-07.zip
# [##################################################]
# File Download: /home/marco/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/BTCUSDT-1m-2022-08.zip
# [##################################################]Found 1 symbols
# [1/1] - start download monthly ETHUSDT klines
#
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2017-08.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2017-09.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2017-10.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2017-11.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2017-12.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2018-01.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2018-02.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2018-03.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2018-04.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2018-05.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2018-06.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2018-07.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2018-08.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2018-09.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2018-10.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2018-11.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2018-12.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2019-01.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2019-02.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2019-03.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2019-04.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2019-05.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2019-06.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2019-07.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2019-08.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2019-09.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2019-10.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2019-11.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2019-12.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2020-01.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2020-02.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2020-03.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2020-04.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2020-05.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2020-06.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2020-07.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2020-08.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2020-09.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2020-10.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2020-11.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2020-12.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2021-01.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2021-02.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2021-03.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2021-04.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2021-05.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2021-06.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2021-07.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2021-08.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2021-09.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2021-10.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2021-11.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2021-12.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2022-01.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2022-02.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2022-03.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2022-04.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2022-05.zip
# [##################################################]
# File Download: /home/marco/marketdata/eth/data/spot/monthly/klines/ETHUSDT/1m/2017-08-01_2022-08-31/ETHUSDT-1m-2022-06.zip
# ^C
# Traceback (most recent call last):
#   File "/home/marco/workspace/Complex-Networks-BTC/binance-public-data/python/download-kline.py", line 113, in <module>
#     download_monthly_klines(args.type, symbols, num_symbols, args.intervals, args.years, args.months, args.startDate, args.endDate, args.folder, args.checksum)
#   File "/home/marco/workspace/Complex-Networks-BTC/binance-public-data/python/download-kline.py", line 46, in download_monthly_klines
#     download_file(path, file_name, date_range, folder)
#   File "/home/marco/workspace/Complex-Networks-BTC/binance-public-data/python/utility.py", line 59, in download_file
#     buf = dl_file.read(blocksize)
#   File "/usr/lib/python3.10/http/client.py", line 466, in read
#     s = self.fp.read(amt)
#   File "/usr/lib/python3.10/socket.py", line 705, in readinto
#     return self._sock.recv_into(b)
#   File "/usr/lib/python3.10/ssl.py", line 1303, in recv_into
#     return self.read(nbytes, buffer)
#   File "/usr/lib/python3.10/ssl.py", line 1159, in read
#     return self._sslobj.read(len, buffer)
# KeyboardInterrupt

# %%
import zipfile, os

def unzipFiles(sym,ticker):
    working_directory = '/marketdata/'+sym+'/data/spot/monthly/klines/'+ticker+'/1m/'+fromDate+'_'+toDate+'/'
    for file in os.listdir(working_directory):   # get the list of files
        print(file)
        if zipfile.is_zipfile(working_directory+file): # if it is a zipfile, extract it
            with zipfile.ZipFile(working_directory+file) as item: # treat the file as a zip
                print(item)
                item.extractall('marketdata/'+sym)

unzipFiles('btc','BTCUSDT')
# unzipFiles('eth','ETHUSDT')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[8], line 12
#       9                 print(item)
#      10                 item.extractall('marketdata/'+sym)
# ---> 12 unzipFiles('btc','BTCUSDT')
#      13 # unzipFiles('eth','ETHUSDT')
#
# Cell In[8], line 5, in unzipFiles(sym, ticker)
#       3 def unzipFiles(sym,ticker):
#       4     working_directory = '/root/marketdata/'+sym+'/data/spot/monthly/klines/'+ticker+'/1m/'+fromDate+'_'+toDate+'/'
# ----> 5     for file in os.listdir(working_directory):   # get the list of files
#       6         print(file)
#       7         if zipfile.is_zipfile(working_directory+file): # if it is a zipfile, extract it
#
# PermissionError: [Errno 13] Permission denied: '/root/marketdata/btc/data/spot/monthly/klines/BTCUSDT/1m/2017-08-01_2022-08-31/'

# %%
S3_BUCKET=!(aws cloudformation list-exports --query "Exports[?Name=='public-blockchain-marketdata'].Value" --output text)
S3_BUCKET=S3_BUCKET[0]

# %%
# !pip install awswrangler

# %%
import zipfile, os
import boto3
import pandas as pd
import awswrangler as wr
from datetime import datetime

s3_path='s3://'+S3_BUCKET+"/marketdata/crypto"

def importFiles(sym,ticker):
    for file in os.listdir("marketdata/"+sym+"/"):   # get the list of files
        if file.endswith(".csv"): # check for ".zip" extension
            file_name = 'marketdata/'+sym+'/'+file # get full path of files
            #print(file_name)
            x=file_name.split('/')[-1:][0].split(".")[0]
            #print(x)
            
            hData=['open_time','open','high','low','close','vol','close_time','quote_asset_vol','number_of_trades','taker_base_asset_vol','taker_quote_asset_vol','ignore']
            df=pd.read_csv(file_name,header=0,names=hData,parse_dates=True)
            df['open_time'] = [datetime.fromtimestamp(x/1000) for x in df['open_time']]
            df['close_time'] = [datetime.fromtimestamp(x/1000) for x in df['close_time']]
            df['ticker']=ticker
            df.set_index(pd.DatetimeIndex(df['open_time']), inplace=True)
       
            s3_file=s3_path+'/'+x+'.snappy.parquet'
            print("upload to %s" % s3_file)
            r=wr.s3.to_parquet(
                    df=df,
                    path=s3_file,
                    dataset=False
            )

importFiles('btc','BTCUSDT')
# importFiles('eth','ETHUSDT')
